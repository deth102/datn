# %% [markdown]
# Thư viện

# %%
import numpy as np
import pandas as pd #đọc đầu vào csv
import matplotlib.pyplot as plt #vẽ đồ thị
from scipy.signal import spectrogram # biểu diễn tren miền thời gian tần số

# %%
fs = 25600  # Tần số lấy mẫu

# %% [markdown]
# Time domain vibration under random speed at normal state

# %%
normalstate= pd.read_csv("Vibration data/Normal_3HP_0%_52Hz.csv") # lấy cột đầu tiên (rung động z-axis)
signal_normalstate = normalstate["vibration_signal"].values
# Loại bỏ các giá trị NaN
valid_normalstate = signal_normalstate[~np.isnan(signal_normalstate)]

Time = np.arange(len(valid_normalstate)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, valid_normalstate, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Normal state")
plt.show()

# %% [markdown]
# The segment of the normal state signal

# %%
t_start = 60.0      # thời điểm bắt đầu 
t_end   = 60.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = valid_normalstate[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Normal state")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under random speed at winding fault (coil-coil; 60 %)

# %%
coil= pd.read_csv("Vibration data/Coil60%_3HP_0%_52Hz.csv")# lấy cột đầu tiên (rung động z-axis)
signal_coil = coil["vibration_signal"].values
valid_coil = signal_coil[~np.isnan(signal_coil)]  # chỉ giữ giá trị thật
Time = np.arange(len(valid_coil)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, valid_coil, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Winding fault (coil-coil; 60 %)")
plt.show()

# %% [markdown]
# The segment of the signal - Winding fault (coil-coil; 60 %)

# %%
t_start = 60.0      # thời điểm bắt đầu 
t_end   = 60.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = valid_coil[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Winding fault (coil-coil; 60 %)")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under random speed at misalignment 50 mm

# %%
misalign= pd.read_csv("Vibration data/Misalign0p5mm_1HP_0%_52Hz.csv") # lấy cột đầu tiên (rung động z-axis)
signal_misalign = misalign["vibration_signal"].values
valid_misalign = signal_misalign[~np.isnan(signal_misalign)]  # chỉ giữ giá trị thật
Time = np.arange(len(valid_misalign)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, valid_misalign, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Misalignment 50 mm")
plt.show()

# %% [markdown]
# The segment of the signal - Misalignment 50 mm

# %%
t_start = 60.0      # thời điểm bắt đầu 
t_end   = 60.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = misalign[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Misalignment 50 mm")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under random speed at Bearing fault

# %%
Bearing= pd.read_csv("Vibration data/Bearing_3HP_30%_52Hz.csv") # lấy cột đầu tiên (rung động z-axis)
signal_bearing = Bearing["vibration_signal"].values
valid_bearing = signal_bearing[~np.isnan(signal_bearing)]  # chỉ giữ giá trị thật
Time = np.arange(len(valid_bearing)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, valid_bearing, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Bearing fault")
plt.show()

# %% [markdown]
# The segment of the signal - Bearing fault

# %%
t_start = 60.0      # thời điểm bắt đầu 
t_end   = 60.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = valid_bearing[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Bearing fault")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under random speed at Journal bearing fault (0. 75 μm)

# %%
Journal_0p75= pd.read_csv("Vibration data/Journal0p75um_7p5HP_30%_52Hz.csv") # lấy cột đầu tiên (rung động z-axis)
signal_journal_0p75 = Journal_0p75["vibration_signal"].values
valid_journal_0p75 = signal_journal_0p75[~np.isnan(signal_journal_0p75)]  # chỉ giữ giá trị thật
Time = np.arange(len(valid_journal_0p75)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, valid_journal_0p75, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Journal bearing fault (0. 75 μm)")
plt.show()

# %% [markdown]
# The segment of the signal - Journal bearing fault (0. 75 μm)

# %%
t_start = 60.0      # thời điểm bắt đầu 
t_end   = 60.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = valid_journal_0p75[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Journal bearing fault (0. 75 μm)")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under random speed at Journal bearing fault (0. 95 μm)

# %%
Journal_0p95= pd.read_csv("Vibration data/Journal0p95um_7p5HP_0%_52Hz.csv") # lấy cột đầu tiên (rung động z-axis)
signal_journal_0p95 = Journal_0p95["vibration_signal"].values
valid_journal_0p95 = signal_journal_0p95[~np.isnan(signal_journal_0p95)]  # chỉ giữ giá trị thật
Time = np.arange(len(valid_journal_0p95)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, valid_journal_0p95, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Journal bearing fault (0. 95 μm)")
plt.show()

# %% [markdown]
# The segment of the signal - Journal bearing fault (0. 95 μm)

# %%
t_start = 60.0      # thời điểm bắt đầu 
t_end   = 60.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = valid_journal_0p95[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Journal bearing fault (0. 95 μm)")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under random speed at normal state

# %%
N = len(valid_normalstate)
fft_vals = np.fft.fft(valid_normalstate - np.mean(valid_normalstate))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Normal State")
plt.xlim(0, 100)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under random speed at winding fault (coil-coil; 60 %)

# %%
N = len(valid_coil)
fft_vals = np.fft.fft(valid_coil - np.mean(valid_coil))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Winding fault (coil-coil; 60 %)")
plt.xlim(0, 100)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under random speed at misalignment 50 mm

# %%
N = len(valid_misalign)
fft_vals = np.fft.fft(valid_misalign - np.mean(valid_misalign))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Misalignment 50 mm")
plt.xlim(0, 100)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under random speed at bearing fault

# %%
N = len(valid_bearing)
fft_vals = np.fft.fft(valid_bearing - np.mean(valid_bearing))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Bearing fault")
plt.xlim(0,100)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under random speed at journal bearing fault (0. 75 μm)

# %%
N = len(valid_journal_0p75)
fft_vals = np.fft.fft(valid_journal_0p75 - np.mean(valid_journal_0p75))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Journal bearing fault (0. 75 μm)")
plt.xlim(0,300)
plt.ylim(0, 7e-3)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under random speed at journal bearing fault (0. 95 μm)

# %%
N = len(valid_journal_0p95)
fft_vals = np.fft.fft(valid_journal_0p95 - np.mean(valid_journal_0p95))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Journal bearing fault (0. 95 μm)")
plt.xlim(0,300)
plt.ylim(0, 85e-3)
plt.grid(True)
plt.tight_layout()
plt.show()
