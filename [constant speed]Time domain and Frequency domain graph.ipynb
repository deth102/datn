# %% [markdown]
# Thư viện

# %%
import numpy as np
import pandas as pd #đọc đầu vào csv
import matplotlib.pyplot as plt #vẽ đồ thị
from scipy.signal import spectrogram # biểu diễn tren miền thời gian tần số

# %%
fs = 25600  # Tần số lấy mẫu

# %% [markdown]
# Time domain vibration under constant at normal state

# %%
normalstate= pd.read_csv("Vibration data/4Nm_Normal.csv") 
signal_normalstate = normalstate["Xa"].values
Time = np.arange(len(signal_normalstate)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, signal_normalstate, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Normal state")
plt.show()

# %% [markdown]
# The segment of the normal state signal

# %%
t_start = 0.0      # thời điểm bắt đầu 
t_end   = 0.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = signal_normalstate[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Normal state")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under constant speed at BPFI

# %%
BPFI= pd.read_csv("Vibration data/4Nm_BPFI_10.csv")# lấy cột đầu tiên (rung động z-axis)
signal_BPFI = BPFI["Xa"].values
Time = np.arange(len(BPFI)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, signal_BPFI, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("BPFI 1mm")
plt.show()

# %% [markdown]
# The segment of the signal - BPFI

# %%
t_start = 0      # thời điểm bắt đầu 
t_end   = 0.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = signal_BPFI[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - BPFI 1mm")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under random speed at BPFO

# %%
BPFO= pd.read_csv("Vibration data/2Nm_BPFO_03.csv")
signal_BPFO = BPFO["Xa"].values
Time = np.arange(len(BPFO)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, signal_BPFO, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("BPFO 1mm")
plt.show()

# %% [markdown]
# The segment of the signal - BPFO 1mm

# %%
t_start = 0      # thời điểm bắt đầu 
t_end   = 0.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = signal_BPFO[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - BPFO 1mm")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under constant speed at Misalign fault

# %%
Misalign= pd.read_csv("Vibration data/4Nm_Misalign_03.csv") # lấy cột đầu tiên (rung động z-axis)
signal_Misalign = Misalign["Xa"].values
Time = np.arange(len(signal_Misalign)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, signal_Misalign, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Misalign 0.3mm")
plt.show()

# %% [markdown]
# The segment of the signal - Misalign 0.3mm

# %%
t_start = 0.0      # thời điểm bắt đầu 
t_end   = 0.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = signal_Misalign[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Misalign 0.3mm")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Time domain vibration under constant speed at Unbalance fault

# %%
Unbalance= pd.read_csv("Vibration data/4Nm_Unbalance_1169mg.csv") # lấy cột đầu tiên (rung động z-axis)
signal_Unbalance = Unbalance["Xa"].values
Time = np.arange(len(signal_Unbalance)) / fs
# Vẽ dữ liệu dao động
plt.figure(figsize=(12,3))
plt.plot(Time/60, signal_Unbalance, color='black', linewidth=0.8)
plt.xlabel("Time (min)")
plt.ylabel("Amplitude (g)")
plt.title("Unbalance 1169mg")
plt.show()

# %% [markdown]
# The segment of the signal - Unbalance 1169mg

# %%
t_start = 0.0      # thời điểm bắt đầu 
t_end   = 0.08     # thời điểm kết thúc 
start = int(fs * t_start)
end   = int(fs * t_end)

Time_segment = Time[start:end]
segment = signal_Misalign[start:end]

plt.figure(figsize=(12,3))
plt.plot(Time_segment, segment, color='black', linewidth=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (g)")
plt.title("The segment of the signal - Unbalance 1169mg")
plt.xlim(t_start, t_end)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under constant speed at normal state

# %%
N = len(signal_normalstate)
fft_vals = np.fft.fft(signal_normalstate - np.mean(signal_normalstate))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Normal State")
plt.xlim(0, 2500)

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under constant speed at BPFI

# %%
N = len(signal_BPFI)
fft_vals = np.fft.fft(signal_BPFI- np.mean(signal_BPFI))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - BPFI")
plt.xlim(0, 2500)

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under constant speed at BPFO

# %%
N = len(signal_BPFO)
fft_vals = np.fft.fft(signal_BPFO - np.mean(signal_BPFO))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - BPFO")
plt.xlim(0, 2500)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under constant speed at Misalign

# %%
N = len(signal_Misalign)
fft_vals = np.fft.fft(signal_Misalign - np.mean(signal_Misalign))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Misalign")
plt.xlim(0,2500)

plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Frequency domain vibration under constant speed at Unbalance 1169mg

# %%
N = len(signal_Unbalance)
fft_vals = np.fft.fft(signal_Unbalance - np.mean(signal_Unbalance))
fft_freqs = np.fft.fftfreq(N, 1/fs)
idx = fft_freqs > 0
plt.figure(figsize=(13, 4))
plt.plot(fft_freqs[idx], np.abs(fft_vals[idx]) * 2 / N, color='red', linewidth=0.8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Amplitude")
plt.title("Frequency Spectrum - Unbalance 1169mg")
plt.xlim(0,2500)

plt.grid(True)
plt.tight_layout()
plt.show()
